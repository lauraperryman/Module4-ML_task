# %% [markdown]
# # Module 4 Guidance
#
# This notebook is a template for module 4b and 4c, which will be tested in Google Colab, your code needs to run there.
# The structure has been provided to improve consistency and make it easier for markers to understand your code but still give students the flexibility to be creative.  You need to populate the required functions to solve this problem.  All dependencies should be documented in the next cell.
#
# You can:
#     add further cells or text blocks to extend or further explain your solution
#     add further functions
#
# Dont:
#     rename functions

# %%
# Fixed dependencies - do not remove or change.
import pytest
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/gdrive/')

# Import your dependencies
from sklearn.preprocessing import OneHotEncoder, StandardScaler, FunctionTransformer
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.metrics import (accuracy_score, f1_score, roc_auc_score, classification_report, ConfusionMatrixDisplay)
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.compose import ColumnTransformer, make_column_selector as selector
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
import matplotlib.pyplot as plt
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
def import_local_data(file_path: str) -> pd.DataFrame:
    """This function needs to import the data file into collab and return a pandas dataframe
    """
    df = pd.read_csv(file_path)
    return df

# %%
local_file_path = "/content/gdrive/MyDrive/Colab Notebooks/breast-cancer.csv"

# %%
# Dont change
raw_data = import_local_data(local_file_path)

# %% [markdown]
# ### Conduct exploratory data analysis and explain your key findings - Examine the data, explain its key features and what they look like.  Highlight any fields that are anomalous.

# %%
# Summary
print("Shape:", raw_data.shape)
print("Columns:", list(raw_data.columns))
print("\nDtypes:\n", raw_data.dtypes)

qm_counts = (raw_data == '?').sum()
print("\n'?' counts per column:\n", qm_counts)

for col in ['age', 'menopause', 'tumor-size', 'inv-nodes', 'node-caps', 'deg-malig', 'breast', 'breast-quad', 'irradiat', 'Class']:
  if col in raw_data.columns:
    print(f"\nUnique values in {col}:\n")
    print(pd.Series(raw_data[col].unique()).head(20))
# Out:
# Shape: (286, 10)
# Columns: ['age', 'menopause', 'tumor-size', 'inv-nodes', 'node-caps', 'deg-malig', 'breast', 'breast-quad', 'irradiat', 'Class']
#
# Dtypes:
#  age            object
# menopause      object
# tumor-size     object
# inv-nodes      object
# node-caps      object
# deg-malig       int64
# breast         object
# breast-quad    object
# irradiat       object
# Class          object
# dtype: object
#
# '?' counts per column:
#  age            0
# menopause      0
# tumor-size     0
# inv-nodes      0
# node-caps      8
# deg-malig      0
# breast         0
# breast-quad    1
# irradiat       0
# Class          0
# dtype: int64
#
# Unique values in age:
#
# 0    40-49
# 1    50-59
# 2    60-69
# 3    30-39
# 4    70-79
# 5    20-29
# dtype: object
#
# Unique values in menopause:
#
# 0    premeno
# 1       ge40
# 2       lt40
# dtype: object
#
# Unique values in tumor-size:
#
# 0      15-19
# 1      35-39
# 2      30-34
# 3      25-29
# 4      40-44
# 5     Oct-14
# ...

# %% [markdown]
# * age - sequence
# * menopause - categorical
# * tumor_size - sequence, inconsistent formatting, need to clean dates into number ranges
# * inv_nodes - sequence, inconsistent formatting, need to clean dates into number ranges
# * node_caps - binary, missing/ambiguous data, remove ? with NaN as affecting small number
# * deg_malig - categorical
# * breast - binary
# * breast_quad - categorical, missing/ambiguous data, replace ? with NaN as affecting small number
# * irradiat - binary
# * class - categorical, convert values to 1,0 as the target class

# %%
# Explain your key findings
# Based on the exploratory data analysis, here are the key findings:

#The dataset initially contained 286 entries and 10 features. Most features were of object type, indicating categorical or ordinal data, with one integer column (deg-malig).
#Several columns, specifically tumor-size and inv-nodes, contained inconsistent string formats for numerical ranges (e.g., 'Oct-14' instead of '10-14').
#Missing values, denoted by '?', were identified in the node-caps (8 instances) and breast-quad (1 instance) columns.
#The target variable, Class, consists of two categories: 'recurrence-events' and 'no-recurrence-events'.
#Data cleaning involved standardizing the format of range values in tumor-size and inv-nodes. Rows containing '?' were removed, which addressed the missing data in node-caps and breast-quad effectively without significant data loss. The node-caps column was also converted into a binary numerical representation.

# %% [markdown]
# Create any data pre-processing that you will conduct on seen and unseen data.  Regardless of the model you use, this dataframe must contain only numeric features and have a strategy for any expected missing values. Any objects can that are needed to handle the test data that are dependent on the training data can be stored in the model class.  You are recommended to use sklearn Pipelines or similar functionality to ensure reproducibility.

# %%
# cleaning
def clean_tumor(value):
        if value == 'Oct-14':
            return '10-14'
        elif value == '05-Sep':
            return '5-9'
        else:
            return value

def clean_inv_nodes(value):
        if value == '03-May':
            return '3-5'
        elif value == '06-Aug':
            return '6-8'
        elif value == '09-Nov':
            return '9-11'
        elif value == 'Dec-14':
            return '12-14'
        else:
            return value
def apply_fixes(df: pd.DataFrame) -> pd.DataFrame:
  """Apply dataset-specific corrections and convert '?' -> NaN. Do not drop rows. """
  df = df.copy()
  if 'tumor-size' in df.columns:
    df['tumor-size'] = df['tumor-size'].apply(clean_tumor)
  if 'inv-nodes' in df.columns:
    df['inv-nodes'] = df['inv-nodes'].apply(clean_inv_nodes)
# Replace '?' with NaN globally
  df = df.replace('?', np.nan)
  return df
# A transformer to use inside sklearn Pipelines
preclean = FunctionTransformer(apply_fixes)

# %%
def build_preprocessor():
  """
  ColumnTransformer that:
    - imputes numeric with median and scales,
    - imputes categorical with most_frequent and one-hot encodes
  """
  numeric_preproc = Pipeline(steps=[
      ('imputer', SimpleImputer(strategy='median')),
      ('scaler', StandardScaler())
  ])
  categorical_preproc = Pipeline(steps=[
      ('imputer', SimpleImputer(strategy='most_frequent')),
      ('onehot', OneHotEncoder(handle_unknown='ignore'))
  ])
  preprocessor = ColumnTransformer(transformers=[
      ('nume', numeric_preproc, selector(dtype_include=np.number)),
      ('cat', categorical_preproc, selector(dtype_include=object))
  ],
                                   remainder='drop')
  return preprocessor

# %%
class Module4_Model:

    def __init__(self):
      # storing training dependent objects here
        self.fitted_pipe = None # holds preclean and ColumnTransformer fitted on train

    def preprocess_training_data(self, training_df: pd.DataFrame):
        """
        This function should process the training data and store any features required in the class
        Process training features:
          -Apply fixes ('?' -> NaN, range corrections),
          -Fit imputers/encoder/scaler only on training data,
          -return numeric-only matric with no missing values,
          -Store the fitted pipeline for use on test/unseen
        """
        preprocessor = build_preprocessor()
       # end to end pipeline: domain fixes -> impute/scale/encode
        self.fitted_pipe = Pipeline(steps=[
           ('preclean', preclean),
           ('preprocessor', preprocessor)
       ])
       #Fit on train only and transform
        processed_df = self.fitted_pipe.fit_transform(training_df)

        return processed_df

    def preprocess_test_data(self, test_df: pd.DataFrame):
      """
      Process test features using train fitted pipeline.
      Returns numeric-only numpy array aligned to training featuress
      """
      assert self.fitted_pipe is not None, "Must fit pipeline before using it. Call preprocess_training_data first."
      processed_df = self.fitted_pipe.transform(test_df)
      return processed_df

# %%
# Split your data so that you can test the effectiveness of your model
x = raw_data.drop('Class', axis=1)
y = raw_data['Class'].map({'no-recurrence-events': 0, 'recurrence-events': 1})

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, stratify=y, random_state=42)

# %%
# Populate preprocess_training_data and preprocess_test_data to preprocess data.
# You must process test and train separately so your model does not accidently gain information that a model wouldnt have in reality and therefore get better predictions

# %%
# Dont change
my_model = Module4_Model()

# %%
# Dont change
x_train_processed = my_model.preprocess_training_data(x_train)

# %%
x_test_processed = my_model.preprocess_test_data(x_test)

# %%
# Create a model

# Baseline Logistic regression (balanced)
balanced_clf = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=42)

# %%
# Dont change
x_test_processed = my_model.preprocess_test_data(x_test)

# %%
# Train your model
balanced_clf.fit(x_train_processed, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)

# %%
# use your model to make a prediction on unseen data
y_pred = clf.predict(x_test_processed)

# %%
# Asssess the accuracy of your model and explain your key findings
# --- Assess accuracy & key findings ---
acc = accuracy_score(y_test_num, y_pred)
print(f"Test Accuracy: {acc:.3f}\n")
print("Classification report:\n")
print(classification_report(y_test_num, y_pred, digits=3))

# --- Visualise confusion matrix ---
fig, ax = plt.subplots(figsize=(4, 4))
ConfusionMatrixDisplay.from_predictions(y_test_num, y_pred, ax=ax, colorbar=False)
ax.set_title("Confusion Matrix (Test)")
plt.show()
# Out:
# Test Accuracy: 0.586
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0      0.711     0.675     0.692        40
#            1      0.350     0.389     0.368        18
#
#     accuracy                          0.586        58
#    macro avg      0.530     0.532     0.530        58
# weighted avg      0.599     0.586     0.592        58

# %%
# End-to-end pipeline for CV (fits preclean & preprocessor inside each fold)
pipe = Pipeline(steps=[
    ('preclean', preclean),
    ('preprocessor', build_preprocessor()),
    ('clf', LogisticRegression(max_iter=2000, class_weight='balanced', random_state=42))
])

# Candidate models & parameters
param_grid = [
    {
        'clf': [LogisticRegression(max_iter=2000, class_weight='balanced', random_state=42)],
        'clf__C': [0.1, 1.0, 10.0],
        'clf__penalty': ['l2'],
        'clf__solver': ['lbfgs']
    },
    {
        'clf': [RandomForestClassifier(random_state=42, class_weight='balanced')],
        'clf__n_estimators': [200, 500],
        'clf__max_depth': [None, 5, 10],
        'clf__max_features': ['sqrt', 'log2']
    },
    {
        'clf': [GradientBoostingClassifier(random_state=42)],
        'clf__learning_rate': [0.05, 0.1],
        'clf__n_estimators': [200, 400],
        'clf__max_depth': [2, 3]
    },
    {
        'clf': [SVC(probability=True, class_weight='balanced', random_state=42)],
        'clf__C': [0.5, 1.0, 2.0],
        'clf__kernel': ['rbf'],
        'clf__gamma': ['scale', 0.1]
    }
]

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
grid = GridSearchCV(
    estimator=pipe,
    param_grid=param_grid,
    scoring='roc_auc',   # change to 'f1' if preferred
    cv=cv,
    n_jobs=-1,
    verbose=1
)

# Fit CV on the full raw X/y (the pipeline handles transforms per fold)
grid.fit(x, y)
print("\nBest CV params:", grid.best_params_)
print(f"Best mean CV ROC-AUC: {grid.best_score_:.3f}")
# Out:
# Fitting 5 folds for each of 29 candidates, totalling 145 fits
#
# Best CV params: {'clf': SVC(class_weight='balanced', probability=True, random_state=42), 'clf__C': 0.5, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# Best mean CV ROC-AUC: 0.701

# %%
#Final Model
best_pipe = grid.best_estimator_
best_pipe.fit(x_train, y_train)  # raw data in; pipe handles all transforms

y_test_proba = best_pipe.predict_proba(x_test)[:, 1]
y_test_pred  = (y_test_proba >= 0.5).astype(int)

print(f"\nFinal Test Accuracy: {accuracy_score(y_test, y_test_pred):.3f}")
print(f"Final Test F1: {f1_score(y_test, y_test_pred):.3f}")
print(f"Final Test ROC-AUC: {roc_auc_score(y_test, y_test_proba):.3f}")

fig, ax = plt.subplots(figsize=(4, 4))
ConfusionMatrixDisplay.from_predictions(y_test, y_test_pred, ax=ax, colorbar=False)
ax.set_title("Confusion Matrix (Final Tuned Model)")
plt.show()
# Out:
# Final Test Accuracy: 0.707
# Final Test F1: 0.320
# Final Test ROC-AUC: 0.641

# %%
#Unseen example
unseen = pd.DataFrame([{
    'age': '50-59',
    'menopause': 'premeno',
    'tumor-size': '15-19',          # raw range string
    'inv-nodes': '3-5',             # raw range string
    'node-caps': 'yes',             # may be NaN in real life; pipeline handles imputation
    'deg-malig': 2,
    'breast': 'left',
    'breast-quad': 'left_low',
    'irradiat': 'no'
}])

unseen_pred_proba = best_pipe.predict_proba(unseen)[:, 1][0]
unseen_pred = int(unseen_pred_proba >= 0.5)
print(f"Unseen example → Probability of recurrence: {unseen_pred_proba:.3f} | Predicted class: {unseen_pred}")
# Out:
# Unseen example → Probability of recurrence: 0.510 | Predicted class: 1

# %% [markdown]
# ### Unit tests:

# %% [markdown]
# #### Checking training and test data for null values. This will work for both pd dataframes and np arrays, and ensures no null values exist.

# %%
def test_no_nulls(data):
    """ Assert no null values within pd dataframe or np array """

    # if data is numpy array, handle accordingly
    if isinstance(data, (np.ndarray)):
        assert not np.isnan(np.min(data))

    # if not np array, assume data is pandas dataframe
    else:
        assert data.isna().sum().sum() == 0

# %%
# run null data unit test on both training and test data
test_no_nulls(x_train_processed)
test_no_nulls(x_test_processed)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-589157459.py in <cell line: 0>()
#       1 # run null data unit test on both training and test data
# ----> 2 test_no_nulls(x_train_processed)
#       3 test_no_nulls(x_test_processed)
#
# /tmp/ipython-input-4069533226.py in test_no_nulls(data)
#       8     # if not np array, assume data is pandas dataframe
#       9     else:
# ---> 10         assert data.isna().sum().sum() == 0
#
# AttributeError: 'csr_matrix' object has no attribute 'isna'
